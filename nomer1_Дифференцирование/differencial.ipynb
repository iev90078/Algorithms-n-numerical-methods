# %%
import numpy as np
import matplotlib.pyplot as plt
from numpy import cos, sin

# %%
#начальная функция
def f(x):
    return np.tan(x)

# %%
#аналитические производные
def df(x):
    return np.cos(x)**(-2)

def d2f(x):
    return 2*(np.cos(x)**(-3))*sin(x)

# %%
#функция для численного дифференцирования
def fch(x):
    global h
    return (f(x+h)-f(x-h))/(2*h)

# %%
h=0.0001

x=np.arange(-1.5, 1.5, h)

# %% [markdown]
# Функеция начальная:

# %%
y=f(x)
plt.plot(x, y)

# %% [markdown]
# Аналитическая проивзодная

# %%
dy=df(x)
plt.plot(x, dy)

# %% [markdown]
# Численная производная

# %%
ych=fch(x)
plt.plot(x, ych)

# %% [markdown]
# # Ошибка между методами

# %%
plt.plot(x, abs(dy-ych))

# %%
e_mash=2**-53
a=np.pi/4
e=np.linspace(a-h, a+h, 10000000)
Ml=max(d2f(e))
Mo=max(f(e))

h_opt=2*(Mo*e_mash/Ml)**0.5

print("Оптимальный шаг: ", h_opt)
# Out:
# Оптимальный шаг:  1.0535658403828931e-08

# %%
E=[]
h_mass=np.arange(h_opt/10, 10*h_opt, h_opt/1000)
for h in h_mass:
    e=np.linspace(a-h, a+h, 10000)
    Ml=max(d2f(e))
    Mo=max(f(e))
    err_met=Ml*h/2
    err_round=(Mo*2)*e_mash/h
    #err_min=2*(Mo*Ml*e_mash)**0.5
    E+=[err_met+err_round]
    #E+=[err_min]

# %% [markdown]
# Ошибка в зависимости от шага

# %%
plt.plot(h_mass, np.array(E))
#plt.plot(h_opt, )
plt.show()

# %%
print(min(E), h_opt, abs(min(E)-h_opt))
# Out:
# 4.214685005376045e-08 1.0535658403828931e-08 3.161119164993152e-08
